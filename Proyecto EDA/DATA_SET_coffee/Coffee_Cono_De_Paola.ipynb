# %%
import pandas as pd
import numpy as np
import glob
import os

# %%
df_quality_coffee=pd.read_csv('./coffee.csv')
df_quality_coffee
# Out:
#     Location.Country                Location.Region  Location.Altitude.Min
# 0      United States                           kona                      0  \
# 1             Brazil  sul de minas - carmo de minas                     12
# 2             Brazil  sul de minas - carmo de minas                     12
# 3           Ethiopia                         sidamo                      0
# 4           Ethiopia                         sidamo                      0
# ..               ...                            ...                    ...
# 984        Guatemala                     san marcos                   1700
# 985         Honduras                      comayagua                   1400
# 986            India    chikmagalur karnataka indua                   3170
# 987            India    chikmagalur karnataka india                   3140
# 988         Honduras                 western region                   1200
#
#      Location.Altitude.Max  Location.Altitude.Average  Year
# ...

# %%
df_quality_coffee["Data.Scores.Total"]== 0
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 984    False
# 985     True
# 986    False
# 987    False
# 988    False
# Name: Data.Scores.Total, Length: 989, dtype: bool

# %%
df_quality_coffee["Data.Scores.Total"].max()
# Out:
# 90.58

# %%
score_cero= df_quality_coffee[df_quality_coffee['Data.Scores.Total']== 0]
score_cero
# Out:
#     Location.Country Location.Region  Location.Altitude.Min
# 985         Honduras       comayagua                   1400  \
#
#      Location.Altitude.Max  Location.Altitude.Average  Year       Data.Owner
# 985                   1400                       1400  2017  bismarck castro  \
#
#     Data.Type.Species Data.Type.Variety Data.Type.Processing method  ...
# 985           Arabica           Caturra                         NaN  ...  \
#
#      Data.Scores.Flavor  Data.Scores.Aftertaste  Data.Scores.Acidity
# 985                 0.0                     0.0                  0.0  \
#
#      Data.Scores.Body  Data.Scores.Balance  Data.Scores.Uniformity
# 985               0.0                  0.0                     0.0  \
#
#      Data.Scores.Sweetness  Data.Scores.Moisture  Data.Scores.Total
# 985                    0.0                  0.12                0.0  \
#
#      Data.Color
# 985       Green
#
# [1 rows x 23 columns]

# %%
df_quality_coffee[df_quality_coffee['Data.Scores.Total']> 89]
# Out:
#     Location.Country Location.Region  Location.Altitude.Min
# 530         Ethiopia    guji-hambela                   1950  \
# 531         Ethiopia    guji-hambela                   1950
#
#      Location.Altitude.Max  Location.Altitude.Average  Year Data.Owner
# 530                   2200                       2075  2014  metad plc  \
# 531                   2200                       2075  2014  metad plc
#
#     Data.Type.Species Data.Type.Variety Data.Type.Processing method  ...
# 530           Arabica               NaN                Washed / Wet  ...  \
# 531           Arabica             Other                Washed / Wet  ...
#
#      Data.Scores.Flavor  Data.Scores.Aftertaste  Data.Scores.Acidity
# 530                8.83                    8.67                 8.75  \
# 531                8.67                    8.50                 8.58
#
#      Data.Scores.Body  Data.Scores.Balance  Data.Scores.Uniformity
# ...

# %%
df_quality_coffee.describe()
# Out:
#        Location.Altitude.Min  Location.Altitude.Max
# count             989.000000             989.000000  \
# mean             1640.076845            1675.929221
# std              9192.519762            9191.957731
# min                 0.000000               0.000000
# 25%               905.000000             950.000000
# 50%              1300.000000            1310.000000
# 75%              1550.000000            1600.000000
# max            190164.000000          190164.000000
#
#        Location.Altitude.Average         Year  Data.Production.Number of bags
# count                 989.000000   989.000000                      989.000000  \
# mean                 1657.998989  2013.549039                      151.761375
# std                  9192.058989     1.658883                      125.665490
# min                     0.000000  2010.000000                        1.000000
# 25%                   950.000000  2012.000000                       15.000000
# ...

# %%
df_quality_coffee[(df_quality_coffee["Location.Country"]== "Colombia")]
# Out:
#     Location.Country Location.Region  Location.Altitude.Min
# 25          Colombia        la plata                   1600  \
# 28          Colombia           huila                   1750
# 30          Colombia           huila                   1750
# 33          Colombia           huila                   1750
# 52          Colombia    cundinamarca                   2136
# ..               ...             ...                    ...
# 899         Colombia        la plata                      0
# 901         Colombia           huila                      0
# 907         Colombia         guayata                   1600
# 935         Colombia           huila                    442
# 942         Colombia         guayata                   1500
#
#      Location.Altitude.Max  Location.Altitude.Average  Year
# 25                    1950                       1775  2011  \
# 28                    1750                       1750  2011
# 30                    1750                       1750  2011
# ...

# %%
df_quality_coffee[(df_quality_coffee["Location.Country"]== "Brazil")]
# Out:
#     Location.Country                Location.Region  Location.Altitude.Min
# 1             Brazil  sul de minas - carmo de minas                     12  \
# 2             Brazil  sul de minas - carmo de minas                     12
# 10            Brazil                 south of minas                   1250
# 11            Brazil                  vale da grama                   1300
# 12            Brazil                 south of minas                   1250
# ..               ...                            ...                    ...
# 894           Brazil                 south of minas                    944
# 896           Brazil                  monte carmelo                    973
# 905           Brazil      alta paulista (sao paulo)                    695
# 908           Brazil                  monte carmelo                      0
# 922           Brazil         campos altos - cerrado                      0
#
#      Location.Altitude.Max  Location.Altitude.Average  Year
# ...

# %% [markdown]
# ### Vasos de 12oz 1.300.000 vasos de agua dar de esta medida
